# %%
'''Normalization is the process of transforming the features (variables) in a dataset to a common scale,
 typically within the range of (0, 1) or (-1, 1). The objective of normalization is to ensure that all 
 features have similar scales, which helps prevent certain features from dominating the modeling process
due to their larger numerical values.

We have already discussed that it will help in rescaling the data into a common scale in a range of (0, 1) or (-1, 1).'''
# Out:
# 'Normalization is the process of transforming the features (variables) in a dataset to a common scale,\n typically within the range of (0, 1) or (-1, 1). The objective of normalization is to ensure that all \n features have similar scales, which helps prevent certain features from dominating the modeling process\ndue to their larger numerical values.\n\nWe have already discussed that it will help in rescaling the data into a common scale in a range of (0, 1) or (-1, 1).'

# %%
'''Yes, in normalization there are mainly 4 different methods of Normalization and they are:

1.Min-Max scaling
2.Mean normalization scaling
3.Max-absolute scaling
4.Robust scaling(Uses IQR method)


These are the several methods to normalize data, and the choice of method depends on
the characteristics of your dataset and the requirements of your modeling task.'''
