# %%
import pandas as pd

# %%
a=pd.read_csv(r"C:\Users\subhadip sinha\OneDrive\CODING\PYTHON\Scikit-Learn\5.ONE HOT ENCODING\aa.csv")
a
# Out:
#                 Car_Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5  69000.0        18000.0       6.0
# 1                  BMW X5  35000.0            NaN       3.0
# 2                  BMW X5      NaN        26100.0       5.0
# 3                  BMW X5  22500.0            NaN       NaN
# 4                  BMW X5  46000.0        31500.0       4.0
# 5                 Audi A5  59000.0        29400.0       5.0
# 6                 Audi A5  52000.0        32000.0       5.0
# 7                 Audi A5      NaN        19300.0       6.0
# 8                 Audi A5  91000.0        12000.0       NaN
# 9   Mercedez Benz C class      NaN        22000.0       6.0
# 10  Mercedez Benz C class  83000.0        20000.0       7.0
# 11  Mercedez Benz C class  79000.0        21000.0       7.0
# 12  Mercedez Benz C class      NaN        33000.0       5.0
# 13                 BMW X5      NaN            NaN       6.0
# 14                    BMW    350.0          340.0       2.0
# ...

# %%
pd.get_dummies(a,drop_first=True)
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Car_Model_BMW  Car_Model_BMW X5  \
# 0   69000.0        18000.0       6.0          False              True
# 1   35000.0            NaN       3.0          False              True
# 2       NaN        26100.0       5.0          False              True
# 3   22500.0            NaN       NaN          False              True
# 4   46000.0        31500.0       4.0          False              True
# 5   59000.0        29400.0       5.0          False             False
# 6   52000.0        32000.0       5.0          False             False
# 7       NaN        19300.0       6.0          False             False
# 8   91000.0        12000.0       NaN          False             False
# 9       NaN        22000.0       6.0          False             False
# 10  83000.0        20000.0       7.0          False             False
# 11  79000.0        21000.0       7.0          False             False
# ...
