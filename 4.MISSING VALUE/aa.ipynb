# %%
import pandas as pd

# %%
a = pd.read_csv(r"C:\Users\subhadip sinha\Desktop\Jupyter Project\aa.csv")
print(a.head())
print(a.isnull().sum())
print(a.shape)
# Out:
#         code                 name       name_short              name_tv  \
# 0  1535420.0   VALENCIA Alejandra       VALENCIA A   Alejandra VALENCIA
# 1  1535429.0          RUIZ Angela           RUIZ A          Angela RUIZ
# 2  1535430.0        GRANDE Matias         GRANDE M        Matias GRANDE
# 3  1536460.0         ROJAS Carlos          ROJAS C         Carlos ROJAS
# 4  1536467.0  MARTINEZ WING Bruno  MARTINEZ WING B  Bruno MARTINEZ WING
#
#    gender function country_code country country_full nationality  \
# 0  Female  Athlete          MEX  Mexico       Mexico      Mexico
# 1  Female  Athlete          MEX  Mexico       Mexico      Mexico
# 2    Male  Athlete          MEX  Mexico       Mexico      Mexico
# 3    Male  Athlete          MEX  Mexico       Mexico      Mexico
# 4    Male  Athlete          MEX  Mexico       Mexico      Mexico
#
#   nationality_full nationality_code  height weight  disciplines  \
# 0           Mexico              MEX     0.0    0.0  ['Archery']
# ...
